# %% [markdown]
# Stemming:
# -Stemming is the process of reducing a word to its word stem that affixes to suffixes and prefixes or to the roots of words known as a lemma. Stemming is important in natural language understanding (NLU) and natural language processing (NLP).
#
# Like when we want to classify a comment is positive or negative and the comments contains words such as eating,eat,eaten etc...then the root word is eat so all the three words can be reduced to eat

# %% [markdown]
# ## PorterStemmer

# %%
from nltk.stem import PorterStemmer
stemming = PorterStemmer()

# %%
words=["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

# %%
for word in words:
  print(word + "----->" + stemming.stem(word))
# Out:
# eating----->eat
# eats----->eat
# eaten----->eaten
# writing----->write
# writes----->write
# programming----->program
# programs----->program
# history----->histori
# finally----->final
# finalized----->final

# %%
#as seen above the major disadvantage of PortStemmer is some words change its entire meaning

# %%
stemming.stem('congratulations')
# Out:
# 'congratul'

# %% [markdown]
# **RegexpStemmer class**
#
# NLTK has RegexpStemmer class with the help of which we can easily implement Regular Expression Stemmer algorithms. It basically takes a single regular expression and removes any prefix or suffix that matches the expression. Let us see an example

# %%
from nltk.stem import RegexpStemmer
reg_stemmer = RegexpStemmer('ing$|s$|e$|able$', min=4)

# %%
reg_stemmer.stem('eating')
# Out:
# 'eat'

# %%
reg_stemmer.stem('ingeating')
# Out:
# 'ingeat'

# %%
reg_stemmer = RegexpStemmer('ing|s$|e$|able$', min=4)

# %%
reg_stemmer.stem('ingeating')
# Out:
# 'eat'

# %% [markdown]
# **Snowball Stemmer**

# %%
from nltk.stem import SnowballStemmer
snow_stemmer = SnowballStemmer('english')

# %%
for word in words:
  print(word + "------>" + snow_stemmer.stem(word))
# Out:
# eating------>eat
# eats------>eat
# eaten------>eaten
# writing------>write
# writes------>write
# programming------>program
# programs------>program
# history------>histori
# finally------>final
# finalized------>final

# %%
stemming.stem("fairly"),stemming.stem("sportingly")
# Out:
# ('fairli', 'sportingli')

# %%
snow_stemmer.stem("fairly"),snow_stemmer.stem("sportingly")
# Out:
# ('fair', 'sport')

# %%
#we saw many of the words still have issue like history, so stemming is nt reliable, so here comes lemmitization
